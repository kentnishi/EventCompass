# %% [markdown]
# The goal of this script is to download event data from CampusGroups from UPB from the Spring 2025 Semester and events from the current Fall 2025 semester.
#
# The entities needed are specified in supabase.
# The features/columns needed for the entities are as specifed in supabase.
#
# After converting the data into a cleaned csv with the appropriate entities, upload to supabase.

# %%
# In the end, I just manually did it for Spring 2025 events. things are not complete tho
